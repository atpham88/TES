# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
result_detroit = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Detroit/Compiled/"
result_atlanta = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Atlanta/Compiled/"
result_la = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/LA/Compiled/"
result_minneapolis = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Minneapolis/Compiled/"
result_ny = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/NY/Compiled/"
result_orlando = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Orlando/Compiled/"
result_phoenix = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Phoenix/Compiled/"
result_seattle = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Seattle/Compiled/"
result_boston = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Boston/Compiled/"
result_boulder = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Boulder/Compiled/"
result_chicago = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Chicago/Compiled/"
result_dallas = "C:/Users/atpha/Documents/Postdocs/Projects/TES/Results/Dallas/Compiled/"

# %%
# Peak load:
pload_detroit = pd.read_excel(result_detroit + 'Peakload.xlsx')
pload_detroit = pload_detroit.sort_values(by=['building id'])
pload_detroit = pload_detroit.reset_index()
pload_detroit = pload_detroit[['building id', 'Peak Load']]

pload_la = pd.read_excel(result_la + 'Peakload_LA.xlsx')
pload_la = pload_la.sort_values(by=['building id'])
pload_la = pload_la.reset_index()
pload_la = pload_la[['building id', 'Peak Load']]

pload_atlanta = pd.read_excel(result_atlanta + 'Peakload_Atlanta.xlsx')
pload_atlanta = pload_atlanta.sort_values(by=['building id'])
pload_atlanta = pload_atlanta.reset_index()
pload_atlanta = pload_atlanta[['building id', 'Peak Load']]

pload_minneapolis = pd.read_excel(result_minneapolis + 'Peakload_Minneapolis.xlsx')
pload_minneapolis = pload_minneapolis.sort_values(by=['building id'])
pload_minneapolis = pload_minneapolis.reset_index()
pload_minneapolis = pload_minneapolis[['building id', 'Peak Load']]

pload_ny = pd.read_excel(result_ny + 'Peakload_NY.xlsx')
pload_ny = pload_ny.sort_values(by=['building id'])
pload_ny = pload_ny.reset_index()
pload_ny = pload_ny[['building id', 'Peak Load']]

pload_orlando = pd.read_excel(result_orlando + 'Peakload_Orlando.xlsx')
pload_orlando = pload_orlando.sort_values(by=['building id'])
pload_orlando = pload_orlando.reset_index()
pload_orlando = pload_orlando[['building id', 'Peak Load']]

pload_phoenix = pd.read_excel(result_phoenix + 'Peakload_Phoenix.xlsx')
pload_phoenix = pload_phoenix.sort_values(by=['building id'])
pload_phoenix = pload_phoenix.reset_index()
pload_phoenix = pload_phoenix[['building id', 'Peak Load']]

pload_seattle = pd.read_excel(result_seattle + 'Peakload_Seattle.xlsx')
pload_seattle = pload_seattle.sort_values(by=['building id'])
pload_seattle = pload_seattle.reset_index()
pload_seattle = pload_seattle[['building id', 'Peak Load']]

pload_boston = pd.read_excel(result_boston + 'Peakload_Boston.xlsx')
pload_boston = pload_boston.sort_values(by=['building id'])
pload_boston = pload_boston.reset_index()
pload_boston = pload_boston[['building id', 'Peak Load']]

pload_boulder = pd.read_excel(result_boulder + 'Peakload_Boulder.xlsx')
pload_boulder = pload_boulder.sort_values(by=['building id'])
pload_boulder = pload_boulder.reset_index()
pload_boulder = pload_boulder[['building id', 'Peak Load']]

pload_chicago = pd.read_excel(result_chicago + 'Peakload_Chicago.xlsx')
pload_chicago = pload_chicago.sort_values(by=['building id'])
pload_chicago = pload_chicago.reset_index()
pload_chicago = pload_chicago[['building id', 'Peak Load']]

pload_dallas = pd.read_excel(result_dallas + 'Peakload_Dallas.xlsx')
pload_dallas = pload_dallas.sort_values(by=['building id'])
pload_dallas = pload_dallas.reset_index()
pload_dallas = pload_dallas[['building id', 'Peak Load']]
pload_dallas
# Out:
#      building id  Peak Load
# 0              1   9.692913
# 1              2  17.932904
# 2              3   7.947452
# 3              4   9.294651
# 4              5  11.450126
# ..           ...        ...
# 395          396   6.042073
# 396          397   9.189935
# 397          398  14.980602
# 398          399   5.098008
# 399          400  13.063250
#
# [400 rows x 2 columns]

# %%
load_detroit = pd.read_excel(result_detroit + 'load.xlsx')
load_detroit = load_detroit.sort_values(by=['building id'])
load_detroit = load_detroit.reset_index()
load_detroit = load_detroit[['building id', 'Load']]
load_detroit['Peak Load'] = pload_detroit['Peak Load']

load_la = pd.read_excel(result_la + 'load.xlsx')
load_la = load_la.sort_values(by=['building id'])
load_la = load_la.reset_index()
load_la = load_la[['building id', 'Load']]
load_la['Peak Load'] = pload_la['Peak Load']

load_atlanta = pd.read_excel(result_atlanta + 'load.xlsx')
load_atlanta = load_atlanta.sort_values(by=['building id'])
load_atlanta = load_atlanta.reset_index()
load_atlanta = load_atlanta[['building id', 'Load']]
load_atlanta['Peak Load'] = pload_atlanta['Peak Load']

load_minneapolis = pd.read_excel(result_minneapolis + 'load.xlsx')
load_minneapolis = load_minneapolis.sort_values(by=['building id'])
load_minneapolis = load_minneapolis.reset_index()
load_minneapolis = load_minneapolis[['building id', 'Load']]
load_minneapolis['Peak Load'] = pload_minneapolis['Peak Load']

load_ny = pd.read_excel(result_ny + 'load.xlsx')
load_ny = load_ny.sort_values(by=['building id'])
load_ny = load_ny.reset_index()
load_ny = load_ny[['building id', 'Load']]
load_ny['Peak Load'] = pload_ny['Peak Load']

load_orlando = pd.read_excel(result_orlando + 'load.xlsx')
load_orlando = load_orlando.sort_values(by=['building id'])
load_orlando = load_orlando.reset_index()
load_orlando = load_orlando[['building id', 'Load']]
load_orlando['Peak Load'] = pload_orlando['Peak Load']

load_phoenix = pd.read_excel(result_phoenix + 'load.xlsx')
load_phoenix = load_phoenix.sort_values(by=['building id'])
load_phoenix = load_phoenix.reset_index()
load_phoenix = load_phoenix[['building id', 'Load']]
load_phoenix['Peak Load'] = pload_phoenix['Peak Load']

load_seattle = pd.read_excel(result_seattle + 'load.xlsx')
load_seattle = load_seattle.sort_values(by=['building id'])
load_seattle = load_seattle.reset_index()
load_seattle = load_seattle[['building id', 'Load']]
load_seattle['Peak Load'] = pload_seattle['Peak Load']

load_boston = pd.read_excel(result_boston + 'load.xlsx')
load_boston = load_boston.sort_values(by=['building id'])
load_boston = load_boston.reset_index()
load_boston = load_boston[['building id', 'Load']]
load_boston['Peak Load'] = pload_boston['Peak Load']

load_boulder = pd.read_excel(result_boulder + 'load.xlsx')
load_boulder = load_boulder.sort_values(by=['building id'])
load_boulder = load_boulder.reset_index()
load_boulder = load_boulder[['building id', 'Load']]
load_boulder['Peak Load'] = pload_boulder['Peak Load']

load_chicago = pd.read_excel(result_chicago + 'load.xlsx')
load_chicago = load_chicago.sort_values(by=['building id'])
load_chicago = load_chicago.reset_index()
load_chicago = load_chicago[['building id', 'Load']]
load_chicago['Peak Load'] = pload_chicago['Peak Load']

load_dallas = pd.read_excel(result_dallas + 'load.xlsx')
load_dallas = load_dallas.sort_values(by=['building id'])
load_dallas = load_dallas.reset_index()
load_dallas = load_dallas[['building id', 'Load']]
load_dallas['Peak Load'] = pload_dallas['Peak Load']
load_dallas
# Out:
#      building id         Load  Peak Load
# 0              1  4256.603393   9.692913
# 1              2  8171.827609  17.932904
# 2              3  3811.808421   7.947452
# 3              4  3912.109549   9.294651
# 4              5  7373.411382  11.450126
# ..           ...          ...        ...
# 395          396  2366.769276   6.042073
# 396          397  4472.409378   9.189935
# 397          398  9203.990694  14.980602
# 398          399  2190.390180   5.098008
# 399          400  6877.260585  13.063250
#
# [400 rows x 3 columns]

# %%
load_atlanta['MgSO4 Salt Mass E'] = load_atlanta['Peak Load']/0.75
load_atlanta['MgSO4 Salt Mass P'] = load_atlanta['Peak Load']/0.281267306
load_atlanta['MgSO4 Salt Mass'] = load_atlanta[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_atlanta['e cap - MgSO4'] = load_atlanta['MgSO4 Salt Mass']*0.75
load_atlanta = load_atlanta.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_detroit['MgSO4 Salt Mass E'] = load_detroit['Peak Load']/0.75
load_detroit['MgSO4 Salt Mass P'] = load_detroit['Peak Load']/0.281267306
load_detroit['MgSO4 Salt Mass'] = load_detroit[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_detroit['e cap - MgSO4'] = load_detroit['MgSO4 Salt Mass']*0.75
load_detroit = load_detroit.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_la['MgSO4 Salt Mass E'] = load_la['Peak Load']/0.75
load_la['MgSO4 Salt Mass P'] = load_la['Peak Load']/0.281267306
load_la['MgSO4 Salt Mass'] = load_la[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_la['e cap - MgSO4'] = load_la['MgSO4 Salt Mass']*0.75
load_la = load_la.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_minneapolis['MgSO4 Salt Mass E'] = load_minneapolis['Peak Load']/0.75
load_minneapolis['MgSO4 Salt Mass P'] = load_minneapolis['Peak Load']/0.281267306
load_minneapolis['MgSO4 Salt Mass'] = load_minneapolis[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_minneapolis['e cap - MgSO4'] = load_minneapolis['MgSO4 Salt Mass']*0.75
load_minneapolis = load_minneapolis.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_ny['MgSO4 Salt Mass E'] = load_ny['Peak Load']/0.75
load_ny['MgSO4 Salt Mass P'] = load_ny['Peak Load']/0.281267306
load_ny['MgSO4 Salt Mass'] = load_ny[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_ny['e cap - MgSO4'] = load_ny['MgSO4 Salt Mass']*0.75
load_ny = load_ny.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_orlando['MgSO4 Salt Mass E'] = load_orlando['Peak Load']/0.75
load_orlando['MgSO4 Salt Mass P'] = load_orlando['Peak Load']/0.281267306
load_orlando['MgSO4 Salt Mass'] = load_orlando[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_orlando['e cap - MgSO4'] = load_orlando['MgSO4 Salt Mass']*0.75
load_orlando = load_orlando.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_phoenix['MgSO4 Salt Mass E'] = load_phoenix['Peak Load']/0.75
load_phoenix['MgSO4 Salt Mass P'] = load_phoenix['Peak Load']/0.281267306
load_phoenix['MgSO4 Salt Mass'] = load_phoenix[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_phoenix['e cap - MgSO4'] = load_phoenix['MgSO4 Salt Mass']*0.75
load_phoenix = load_phoenix.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_seattle['MgSO4 Salt Mass E'] = load_seattle['Peak Load']/0.75
load_seattle['MgSO4 Salt Mass P'] = load_seattle['Peak Load']/0.281267306
load_seattle['MgSO4 Salt Mass'] = load_seattle[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_seattle['e cap - MgSO4'] = load_seattle['MgSO4 Salt Mass']*0.75
load_seattle = load_seattle.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_boston['MgSO4 Salt Mass E'] = load_boston['Peak Load']/0.75
load_boston['MgSO4 Salt Mass P'] = load_boston['Peak Load']/0.281267306
load_boston['MgSO4 Salt Mass'] = load_boston[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_boston['e cap - MgSO4'] = load_seattle['MgSO4 Salt Mass']*0.75
load_boston = load_boston.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_boulder['MgSO4 Salt Mass E'] = load_boulder['Peak Load']/0.75
load_boulder['MgSO4 Salt Mass P'] = load_boulder['Peak Load']/0.281267306
load_boulder['MgSO4 Salt Mass'] = load_boulder[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_boulder['e cap - MgSO4'] = load_boulder['MgSO4 Salt Mass']*0.75
load_boulder = load_boulder.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_chicago['MgSO4 Salt Mass E'] = load_chicago['Peak Load']/0.75
load_chicago['MgSO4 Salt Mass P'] = load_chicago['Peak Load']/0.281267306
load_chicago['MgSO4 Salt Mass'] = load_chicago[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_chicago['e cap - MgSO4'] = load_chicago['MgSO4 Salt Mass']*0.75
load_chicago = load_chicago.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_dallas['MgSO4 Salt Mass E'] = load_dallas['Peak Load']/0.75
load_dallas['MgSO4 Salt Mass P'] = load_dallas['Peak Load']/0.281267306
load_dallas['MgSO4 Salt Mass'] = load_dallas[['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E']].max(axis=1)
load_dallas['e cap - MgSO4'] = load_dallas['MgSO4 Salt Mass']*0.75
load_dallas = load_dallas.drop(['MgSO4 Salt Mass P', 'MgSO4 Salt Mass E'], axis=1)

load_dallas
# Out:
#      building id         Load  Peak Load  MgSO4 Salt Mass  e cap - MgSO4
# 0              1  4256.603393   9.692913        34.461571      25.846178
# 1              2  8171.827609  17.932904        63.757514      47.818135
# 2              3  3811.808421   7.947452        28.255870      21.191902
# 3              4  3912.109549   9.294651        33.045616      24.784212
# 4              5  7373.411382  11.450126        40.709054      30.531790
# ..           ...          ...        ...              ...            ...
# 395          396  2366.769276   6.042073        21.481606      16.111204
# 396          397  4472.409378   9.189935        32.673312      24.504984
# 397          398  9203.990694  14.980602        53.261084      39.945813
# 398          399  2190.390180   5.098008        18.125137      13.593853
# 399          400  6877.260585  13.063250        46.444253      34.833190
#
# [400 rows x 5 columns]

# %%
# Total costs:
rate = 'Fixed_Rate'
size_dt = 'Opt_Size'
size = 'Opt_Size'
cost_noTES_detroit = pd.read_excel(result_detroit + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_detroit = pd.read_excel(result_detroit + 'costs_salt_' + rate + '_' + size_dt + '_MgSO4'+'.xlsx')
cost_noTES_atlanta = pd.read_excel(result_atlanta + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_atlanta = pd.read_excel(result_atlanta + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_la = pd.read_excel(result_la + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_la = pd.read_excel(result_la + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_minneapolis = pd.read_excel(result_minneapolis + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_minneapolis = pd.read_excel(result_minneapolis + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_ny = pd.read_excel(result_ny + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_ny = pd.read_excel(result_ny + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_orlando = pd.read_excel(result_orlando + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_orlando = pd.read_excel(result_orlando + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_phoenix = pd.read_excel(result_phoenix + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_phoenix = pd.read_excel(result_phoenix + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_seattle = pd.read_excel(result_seattle + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_seattle = pd.read_excel(result_seattle + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_boston = pd.read_excel(result_boston + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_boston = pd.read_excel(result_boston + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_boulder = pd.read_excel(result_boulder + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_boulder = pd.read_excel(result_boulder + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_chicago = pd.read_excel(result_chicago + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_chicago = pd.read_excel(result_chicago + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')
cost_noTES_dallas = pd.read_excel(result_dallas + 'costs_noTES_' + rate +'.xlsx')
cost_MgSO4_dallas = pd.read_excel(result_dallas + 'costs_salt_' + rate + '_' + size + '_MgSO4'+'.xlsx')

# Clean up:
cost_noTES_detroit = cost_noTES_detroit.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_detroit = cost_noTES_detroit.sort_values(by=['building id'])
cost_noTES_detroit = cost_noTES_detroit.reset_index()
cost_noTES_detroit = cost_noTES_detroit[['building id', 'total cost ($)']]
cost_MgSO4_detroit = cost_MgSO4_detroit.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_detroit = cost_MgSO4_detroit.sort_values(by=['building id'])
cost_MgSO4_detroit = cost_MgSO4_detroit.reset_index()
cost_MgSO4_detroit = cost_MgSO4_detroit[['building id', 'total cost ($)']]

cost_noTES_atlanta = cost_noTES_atlanta.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_atlanta = cost_noTES_atlanta.sort_values(by=['building id'])
cost_noTES_atlanta = cost_noTES_atlanta.reset_index()
cost_noTES_atlanta = cost_noTES_atlanta[['building id', 'total cost ($)']]
cost_MgSO4_atlanta = cost_MgSO4_atlanta.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_atlanta = cost_MgSO4_atlanta.sort_values(by=['building id'])
cost_MgSO4_atlanta = cost_MgSO4_atlanta.reset_index()
cost_MgSO4_atlanta = cost_MgSO4_atlanta[['building id', 'total cost ($)']]

cost_noTES_la = cost_noTES_la.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_la = cost_noTES_la.sort_values(by=['building id'])
cost_noTES_la = cost_noTES_la.reset_index()
cost_noTES_la = cost_noTES_la[['building id', 'total cost ($)']]
cost_MgSO4_la = cost_MgSO4_la.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_la = cost_MgSO4_la.sort_values(by=['building id'])
cost_MgSO4_la = cost_MgSO4_la.reset_index()
cost_MgSO4_la = cost_MgSO4_la[['building id', 'total cost ($)']]

cost_noTES_minneapolis = cost_noTES_minneapolis.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_minneapolis = cost_noTES_minneapolis.sort_values(by=['building id'])
cost_noTES_minneapolis = cost_noTES_minneapolis.reset_index()
cost_noTES_minneapolis = cost_noTES_minneapolis[['building id', 'total cost ($)']]
cost_MgSO4_minneapolis = cost_MgSO4_minneapolis.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_minneapolis = cost_MgSO4_minneapolis.sort_values(by=['building id'])
cost_MgSO4_minneapolis = cost_MgSO4_minneapolis.reset_index()
cost_MgSO4_minneapolis = cost_MgSO4_minneapolis[['building id', 'total cost ($)']]

cost_noTES_ny = cost_noTES_ny.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_ny = cost_noTES_ny.sort_values(by=['building id'])
cost_noTES_ny = cost_noTES_ny.reset_index()
cost_noTES_ny = cost_noTES_ny[['building id', 'total cost ($)']]
cost_MgSO4_ny = cost_MgSO4_ny.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_ny = cost_MgSO4_ny.sort_values(by=['building id'])
cost_MgSO4_ny = cost_MgSO4_ny.reset_index()
cost_MgSO4_ny = cost_MgSO4_ny[['building id', 'total cost ($)']]

cost_noTES_orlando = cost_noTES_orlando.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_orlando = cost_noTES_orlando.sort_values(by=['building id'])
cost_noTES_orlando = cost_noTES_orlando.reset_index()
cost_noTES_orlando = cost_noTES_orlando[['building id', 'total cost ($)']]
cost_MgSO4_orlando = cost_MgSO4_orlando.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_orlando = cost_MgSO4_orlando.sort_values(by=['building id'])
cost_MgSO4_orlando = cost_MgSO4_orlando.reset_index()
cost_MgSO4_orlando = cost_MgSO4_orlando[['building id', 'total cost ($)']]

cost_noTES_phoenix = cost_noTES_phoenix.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_phoenix = cost_noTES_phoenix.sort_values(by=['building id'])
cost_noTES_phoenix = cost_noTES_phoenix.reset_index()
cost_noTES_phoenix = cost_noTES_phoenix[['building id', 'total cost ($)']]
cost_MgSO4_phoenix = cost_MgSO4_phoenix.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_phoenix = cost_MgSO4_phoenix.sort_values(by=['building id'])
cost_MgSO4_phoenix = cost_MgSO4_phoenix.reset_index()
cost_MgSO4_phoenix = cost_MgSO4_phoenix[['building id', 'total cost ($)']]

cost_noTES_seattle = cost_noTES_seattle.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_seattle = cost_noTES_seattle.sort_values(by=['building id'])
cost_noTES_seattle = cost_noTES_seattle.reset_index()
cost_noTES_seattle = cost_noTES_seattle[['building id', 'total cost ($)']]
cost_MgSO4_seattle = cost_MgSO4_seattle.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_seattle = cost_MgSO4_seattle.sort_values(by=['building id'])
cost_MgSO4_seattle = cost_MgSO4_seattle.reset_index()
cost_MgSO4_seattle = cost_MgSO4_seattle[['building id', 'total cost ($)']]

cost_noTES_boston = cost_noTES_boston.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_boston = cost_noTES_boston.sort_values(by=['building id'])
cost_noTES_boston = cost_noTES_boston.reset_index()
cost_noTES_boston = cost_noTES_boston[['building id', 'total cost ($)']]
cost_MgSO4_boston = cost_MgSO4_boston.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_boston = cost_MgSO4_boston.sort_values(by=['building id'])
cost_MgSO4_boston = cost_MgSO4_boston.reset_index()
cost_MgSO4_boston = cost_MgSO4_boston[['building id', 'total cost ($)']]

cost_noTES_boulder = cost_noTES_boulder.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_boulder = cost_noTES_boulder.sort_values(by=['building id'])
cost_noTES_boulder = cost_noTES_boulder.reset_index()
cost_noTES_boulder = cost_noTES_boulder[['building id', 'total cost ($)']]
cost_MgSO4_boulder = cost_MgSO4_boulder.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_boulder = cost_MgSO4_boulder.sort_values(by=['building id'])
cost_MgSO4_boulder = cost_MgSO4_boulder.reset_index()
cost_MgSO4_boulder = cost_MgSO4_boulder[['building id', 'total cost ($)']]

cost_noTES_chicago = cost_noTES_chicago.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_chicago = cost_noTES_chicago.sort_values(by=['building id'])
cost_noTES_chicago = cost_noTES_chicago.reset_index()
cost_noTES_chicago = cost_noTES_chicago[['building id', 'total cost ($)']]
cost_MgSO4_chicago = cost_MgSO4_chicago.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_chicago = cost_MgSO4_chicago.sort_values(by=['building id'])
cost_MgSO4_chicago = cost_MgSO4_chicago.reset_index()
cost_MgSO4_chicago = cost_MgSO4_chicago[['building id', 'total cost ($)']]

cost_noTES_dallas = cost_noTES_dallas.rename(columns={'Unnamed: 0': 'building id'})
cost_noTES_dallas = cost_noTES_dallas.sort_values(by=['building id'])
cost_noTES_dallas = cost_noTES_dallas.reset_index()
cost_noTES_dallas = cost_noTES_dallas[['building id', 'total cost ($)']]
cost_MgSO4_dallas = cost_MgSO4_dallas.rename(columns={'Unnamed: 0': 'building id'})
cost_MgSO4_dallas = cost_MgSO4_dallas.sort_values(by=['building id'])
cost_MgSO4_dallas = cost_MgSO4_dallas.reset_index()
cost_MgSO4_dallas = cost_MgSO4_dallas[['building id', 'total cost ($)']]

cost_MgSO4_dallas
# Out:
#      building id  total cost ($)
# 0              1      130.281894
# 1              2      249.364618
# 2              3      115.513270
# 3              4      118.307288
# 4              5      224.650982
# ..           ...             ...
# 395          396       72.739724
# 396          397      136.792455
# 397          398      282.147570
# 398          399       66.745412
# 399          400      209.763204
#
# [400 rows x 2 columns]

# %%
# Find changes in total costs - Detroit:
cost_impacts_TES_detroit = pd.DataFrame()
cost_impacts_TES_detroit['building id'] = cost_noTES_detroit['building id']
cost_impacts_TES_detroit['total cost - no TES'] = cost_noTES_detroit['total cost ($)']
cost_impacts_TES_detroit['total cost - MgSO4'] = cost_MgSO4_detroit['total cost ($)']
cost_impacts_TES_detroit['cost saving - MgSO4'] = cost_impacts_TES_detroit['total cost - no TES'] - cost_impacts_TES_detroit['total cost - MgSO4']
cost_impacts_TES_detroit['cost saving % - MgSO4'] = cost_impacts_TES_detroit['cost saving - MgSO4']/cost_impacts_TES_detroit['total cost - no TES']
cost_impacts_TES_detroit['Salt Mass'] = load_detroit['MgSO4 Salt Mass']
cost_impacts_TES_detroit['cost saving kWh'] = cost_impacts_TES_detroit['cost saving - MgSO4']/cost_impacts_TES_detroit['Salt Mass']*20*0.75
cost_impacts_TES_detroit['City'] = 'Detroit'
cost_impacts_TES_detroit
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1          3526.290877         3411.853730
# 1              2          2523.385394         2439.361398
# 2              3          2254.533101         2175.504185
# 3              4          1938.359969         1868.762140
# 4              5          3591.834993         3476.731842
# ..           ...                  ...                 ...
# 395          396          1436.920123         1387.327722
# 396          397          1535.499790         1487.147655
# 397          398           491.584576          473.586949
# 398          399          1766.304961         1707.027850
# 399          400          3539.585834         3424.820699
#
#      cost saving - MgSO4  cost saving % - MgSO4   Salt Mass  cost saving kWh  \
# 0             114.437147               0.032453   98.568777        17.414817
# 1              84.023996               0.033298   71.693170        17.579916
# ...

# %%
# Find changes in total costs - Atlanta:
cost_impacts_TES_atlanta = pd.DataFrame()
cost_impacts_TES_atlanta['building id'] = cost_noTES_atlanta['building id']
cost_impacts_TES_atlanta['total cost - no TES'] = cost_noTES_atlanta['total cost ($)']
cost_impacts_TES_atlanta['total cost - MgSO4'] = cost_MgSO4_atlanta['total cost ($)']
cost_impacts_TES_atlanta['cost saving - MgSO4'] = cost_impacts_TES_atlanta['total cost - no TES'] - cost_impacts_TES_atlanta['total cost - MgSO4']
cost_impacts_TES_atlanta['cost saving % - MgSO4'] = cost_impacts_TES_atlanta['cost saving - MgSO4']/cost_impacts_TES_atlanta['total cost - no TES']
cost_impacts_TES_atlanta['Salt Mass'] = load_atlanta['MgSO4 Salt Mass']
cost_impacts_TES_atlanta['cost saving kWh'] = cost_impacts_TES_atlanta['cost saving - MgSO4']/cost_impacts_TES_atlanta['Salt Mass']*20*0.75
cost_impacts_TES_atlanta['City'] = 'Atlanta'
cost_impacts_TES_atlanta
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1            29.859611           27.267587
# 1              2           399.581658          377.918743
# 2              3           175.643606          165.830797
# 3              4           161.800858          149.723720
# 4              5           245.735508          231.218362
# ..           ...                  ...                 ...
# 395          396           482.776050          460.079940
# 396          397           259.325300          245.578112
# 397          398           438.209046          420.602256
# 398          399           160.026509          150.756976
# 399          400           491.219605          464.059403
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0               2.592024               0.086807   7.603786         5.113290
# 1              21.662916               0.054214  45.234564         7.183528
# ...

# %%
# Find changes in total costs - LA:
cost_impacts_TES_la = pd.DataFrame()
cost_impacts_TES_la['building id'] = cost_noTES_la['building id']
cost_impacts_TES_la['total cost - no TES'] = cost_noTES_la['total cost ($)']
cost_impacts_TES_la['total cost - MgSO4'] = cost_MgSO4_la['total cost ($)']
cost_impacts_TES_la['cost saving - MgSO4'] = cost_impacts_TES_la['total cost - no TES'] - cost_impacts_TES_la['total cost - MgSO4']
cost_impacts_TES_la['cost saving % - MgSO4'] = cost_impacts_TES_la['cost saving - MgSO4']/cost_impacts_TES_la['total cost - no TES']
cost_impacts_TES_la['Salt Mass'] = load_la['MgSO4 Salt Mass']
cost_impacts_TES_la['cost saving kWh'] = cost_impacts_TES_la['cost saving - MgSO4']/cost_impacts_TES_la['Salt Mass']*20*0.75
cost_impacts_TES_la['City'] = 'Los Angeles'
cost_impacts_TES_la
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1           165.163442          158.072868
# 1              2            19.826713           17.885636
# 2              3            60.886312           58.085234
# 3              4            46.937588           43.768198
# 4              5           122.055300          113.504714
# ..           ...                  ...                 ...
# 395          396           273.294141          262.161224
# 396          397           229.509389          219.306772
# 397          398            10.101119            9.343762
# 398          399           311.268470          298.759076
# 399          400           495.327506          476.404091
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0               7.090574               0.042931  13.072209         8.136239
# 1               1.941077               0.097902  10.730556         2.713388
# ...

# %%
# Find changes in total costs - Minny:
cost_impacts_TES_minneapolis = pd.DataFrame()
cost_impacts_TES_minneapolis['building id'] = cost_noTES_minneapolis['building id']
cost_impacts_TES_minneapolis['total cost - no TES'] = cost_noTES_minneapolis['total cost ($)']
cost_impacts_TES_minneapolis['total cost - MgSO4'] = cost_MgSO4_minneapolis['total cost ($)']
cost_impacts_TES_minneapolis['cost saving - MgSO4'] = cost_impacts_TES_minneapolis['total cost - no TES'] - cost_impacts_TES_minneapolis['total cost - MgSO4']
cost_impacts_TES_minneapolis['cost saving % - MgSO4'] = cost_impacts_TES_minneapolis['cost saving - MgSO4']/cost_impacts_TES_minneapolis['total cost - no TES']
cost_impacts_TES_minneapolis['Salt Mass'] = load_minneapolis['MgSO4 Salt Mass']
cost_impacts_TES_minneapolis['cost saving kWh'] = cost_impacts_TES_minneapolis['cost saving - MgSO4']/cost_impacts_TES_minneapolis['Salt Mass']*20*0.75
cost_impacts_TES_minneapolis['City'] = 'Minneapolis'
cost_impacts_TES_minneapolis
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1          1306.698866         1219.292137
# 1              2          1271.213288         1179.544179
# 2              3          1362.853464         1277.291995
# 3              4          1846.949054         1743.102353
# 4              5          1644.996189         1546.405615
# ..           ...                  ...                 ...
# 395          396           628.517430          587.897036
# 396          397           722.305495          675.609518
# 397          398          1280.651218         1185.596679
# 398          399          1074.885070         1003.598008
# 399          400          1464.206236         1362.435883
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0              87.406729               0.066891  52.495903        24.975300
# 1              91.669109               0.072112  55.792552        24.645523
# ...

# %%
# Find changes in total costs - NYC:
cost_impacts_TES_ny = pd.DataFrame()
cost_impacts_TES_ny['building id'] = cost_noTES_ny['building id']
cost_impacts_TES_ny['total cost - no TES'] = cost_noTES_ny['total cost ($)']
cost_impacts_TES_ny['total cost - MgSO4'] = cost_MgSO4_ny['total cost ($)']
cost_impacts_TES_ny['cost saving - MgSO4'] = cost_impacts_TES_ny['total cost - no TES'] - cost_impacts_TES_ny['total cost - MgSO4']
cost_impacts_TES_ny['cost saving % - MgSO4'] = cost_impacts_TES_ny['cost saving - MgSO4']/cost_impacts_TES_ny['total cost - no TES']
cost_impacts_TES_ny['Salt Mass'] = load_ny['MgSO4 Salt Mass']
cost_impacts_TES_ny['cost saving kWh'] = cost_impacts_TES_ny['cost saving - MgSO4']/cost_impacts_TES_ny['Salt Mass']*20*0.75
cost_impacts_TES_ny['City'] = 'New York City'
cost_impacts_TES_ny
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1          1441.440953         1401.724611
# 1              2          2065.776181         1996.139829
# 2              3          1954.071449         1899.937915
# 3              4          1555.088676         1508.595901
# 4              5          1082.833878         1044.605965
# ..           ...                  ...                 ...
# 395          396           394.411847          380.590246
# 396          397          1979.867645         1925.465194
# 397          398          1658.914091         1614.026366
# 398          399          2033.160950         1980.946681
# 399          400          1015.067066          984.940252
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0              39.716342               0.027553  43.628526        13.654945
# 1              69.636352               0.033710  89.151858        11.716472
# ...

# %%
# Find changes in total costs - Orlando:
cost_impacts_TES_orlando = pd.DataFrame()
cost_impacts_TES_orlando['building id'] = cost_noTES_orlando['building id']
cost_impacts_TES_orlando['total cost - no TES'] = cost_noTES_orlando['total cost ($)']
cost_impacts_TES_orlando['total cost - MgSO4'] = cost_MgSO4_orlando['total cost ($)']
cost_impacts_TES_orlando['cost saving - MgSO4'] = cost_impacts_TES_orlando['total cost - no TES'] - cost_impacts_TES_orlando['total cost - MgSO4']
cost_impacts_TES_orlando['cost saving % - MgSO4'] = cost_impacts_TES_orlando['cost saving - MgSO4']/cost_impacts_TES_orlando['total cost - no TES']
cost_impacts_TES_orlando['Salt Mass'] = load_orlando['MgSO4 Salt Mass']
cost_impacts_TES_orlando['cost saving kWh'] = cost_impacts_TES_orlando['cost saving - MgSO4']/cost_impacts_TES_orlando['Salt Mass']*20*0.75
cost_impacts_TES_orlando['City'] = 'Orlando'
cost_impacts_TES_orlando
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1            63.126307           57.684722
# 1              2            19.907215           17.788833
# 2              3            24.803398           22.533242
# 3              4            43.170346           38.664548
# 4              5            67.489166           61.963575
# ..           ...                  ...                 ...
# 395          396             6.868322            6.041082
# 396          397            15.311195           13.877254
# 397          398            66.828495           61.321544
# 398          399             9.616911            8.540445
# 399          400            49.983245           45.221264
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0               5.441585               0.086202  22.952078         3.556270
# 1               2.118382               0.106413  26.743548         1.188164
# ...

# %%
# Find changes in total costs - Phoenix:
cost_impacts_TES_phoenix = pd.DataFrame()
cost_impacts_TES_phoenix['building id'] = cost_noTES_phoenix['building id']
cost_impacts_TES_phoenix['total cost - no TES'] = cost_noTES_phoenix['total cost ($)']
cost_impacts_TES_phoenix['total cost - MgSO4'] = cost_MgSO4_phoenix['total cost ($)']
cost_impacts_TES_phoenix['cost saving - MgSO4'] = cost_impacts_TES_phoenix['total cost - no TES'] - cost_impacts_TES_phoenix['total cost - MgSO4']
cost_impacts_TES_phoenix['cost saving % - MgSO4'] = cost_impacts_TES_phoenix['cost saving - MgSO4']/cost_impacts_TES_phoenix['total cost - no TES']
cost_impacts_TES_phoenix['Salt Mass'] = load_phoenix['MgSO4 Salt Mass']
cost_impacts_TES_phoenix['cost saving kWh'] = cost_impacts_TES_phoenix['cost saving - MgSO4']/cost_impacts_TES_phoenix['Salt Mass']*20*0.75
cost_impacts_TES_phoenix['City'] = 'Phoenix'
cost_impacts_TES_phoenix
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1             4.926286            4.227132
# 1              2            47.537381           43.746303
# 2              3            21.815541           19.682584
# 3              4            24.493285           21.464731
# 4              5            33.165207           30.227519
# ..           ...                  ...                 ...
# 395          396            46.945896           41.468920
# 396          397            90.737492           84.093309
# 397          398             6.992997            5.892648
# 398          399            24.382012           22.624707
# 399          400            39.181292           35.963570
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0               0.699154               0.141923   4.694047         2.234172
# 1               3.791079               0.079749  12.344781         4.606496
# ...

# %%
# Find changes in total costs - Seattle:
cost_impacts_TES_seattle = pd.DataFrame()
cost_impacts_TES_seattle['building id'] = cost_noTES_seattle['building id']
cost_impacts_TES_seattle['total cost - no TES'] = cost_noTES_seattle['total cost ($)']
cost_impacts_TES_seattle['total cost - MgSO4'] = cost_MgSO4_seattle['total cost ($)']
cost_impacts_TES_seattle['cost saving - MgSO4'] = cost_impacts_TES_seattle['total cost - no TES'] - cost_impacts_TES_seattle['total cost - MgSO4']
cost_impacts_TES_seattle['cost saving % - MgSO4'] = cost_impacts_TES_seattle['cost saving - MgSO4']/cost_impacts_TES_seattle['total cost - no TES']
cost_impacts_TES_seattle['Salt Mass'] = load_seattle['MgSO4 Salt Mass']
cost_impacts_TES_seattle['cost saving kWh'] = cost_impacts_TES_seattle['cost saving - MgSO4']/cost_impacts_TES_seattle['Salt Mass']*20*0.75
cost_impacts_TES_seattle['City'] = 'Seattle'
cost_impacts_TES_seattle
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1           186.979542          180.683404
# 1              2           454.041718          442.897238
# 2              3           185.092382          179.988685
# 3              4           334.892254          326.482642
# 4              5           191.718963          186.854365
# ..           ...                  ...                 ...
# 395          396           384.750903          375.020607
# 396          397           373.537570          363.957727
# 397          398           213.305171          208.400945
# 398          399           133.402960          129.145316
# 399          400           564.781747          551.065809
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0               6.296138               0.033673  22.664020         4.167049
# 1              11.144481               0.024545  30.836916         5.421009
# ...

# %%
# Find changes in total costs - Boston:
cost_impacts_TES_boston = pd.DataFrame()
cost_impacts_TES_boston['building id'] = cost_noTES_boston['building id']
cost_impacts_TES_boston['total cost - no TES'] = cost_noTES_boston['total cost ($)']
cost_impacts_TES_boston['total cost - MgSO4'] = cost_MgSO4_boston['total cost ($)']
cost_impacts_TES_boston['cost saving - MgSO4'] = cost_impacts_TES_boston['total cost - no TES'] - cost_impacts_TES_boston['total cost - MgSO4']
cost_impacts_TES_boston['cost saving % - MgSO4'] = cost_impacts_TES_boston['cost saving - MgSO4']/cost_impacts_TES_boston['total cost - no TES']
cost_impacts_TES_boston['Salt Mass'] = load_boston['MgSO4 Salt Mass']
cost_impacts_TES_boston['cost saving kWh'] = cost_impacts_TES_boston['cost saving - MgSO4']/cost_impacts_TES_boston['Salt Mass']*20*0.75
cost_impacts_TES_boston['City'] = 'Boston'
cost_impacts_TES_boston
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1          4008.950618         3874.873613
# 1              2          2775.629309         2672.199095
# 2              3          2263.127938         2166.970403
# 3              4          1886.169832         1817.657323
# 4              5           868.638583          830.940300
# ..           ...                  ...                 ...
# 395          396          1626.621115         1569.050037
# 396          397          3187.074415         3068.212640
# 397          398          1521.849730         1461.671629
# 398          399          1620.387502         1555.460667
# 399          400          3231.157035         3123.846691
#
#      cost saving - MgSO4  cost saving % - MgSO4   Salt Mass  cost saving kWh  \
# 0             134.077005               0.033444  100.015936        20.108346
# 1             103.430214               0.037264   79.000298        19.638574
# ...

# %%
# Find changes in total costs - Boulder:
cost_impacts_TES_boulder = pd.DataFrame()
cost_impacts_TES_boulder['building id'] = cost_noTES_boulder['building id']
cost_impacts_TES_boulder['total cost - no TES'] = cost_noTES_boulder['total cost ($)']
cost_impacts_TES_boulder['total cost - MgSO4'] = cost_MgSO4_boulder['total cost ($)']
cost_impacts_TES_boulder['cost saving - MgSO4'] = cost_impacts_TES_boulder['total cost - no TES'] - cost_impacts_TES_boulder['total cost - MgSO4']
cost_impacts_TES_boulder['cost saving % - MgSO4'] = cost_impacts_TES_boulder['cost saving - MgSO4']/cost_impacts_TES_boulder['total cost - no TES']
cost_impacts_TES_boulder['Salt Mass'] = load_boulder['MgSO4 Salt Mass']
cost_impacts_TES_boulder['cost saving kWh'] = cost_impacts_TES_boulder['cost saving - MgSO4']/cost_impacts_TES_boulder['Salt Mass']*20*0.75
cost_impacts_TES_boulder['City'] = 'Boulder'
cost_impacts_TES_boulder
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1           298.441692          263.130144
# 1              2          1223.234505         1098.271436
# 2              3           359.220111          322.843782
# 3              4          1018.812317          936.858229
# 4              5           547.296537          491.844198
# ..           ...                  ...                 ...
# 395          396           591.666866          534.575985
# 396          397           236.567598          212.923646
# 397          398          1034.739691          944.534060
# 398          399           339.641303          306.188855
# 399          400           498.175730          451.046336
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0              35.311548               0.118320  29.363759        18.038332
# 1             124.963069               0.102158  97.145881        19.295167
# ...

# %%
# Find changes in total costs - Chicago:
cost_impacts_TES_chicago = pd.DataFrame()
cost_impacts_TES_chicago['building id'] = cost_noTES_chicago['building id']
cost_impacts_TES_chicago['total cost - no TES'] = cost_noTES_chicago['total cost ($)']
cost_impacts_TES_chicago['total cost - MgSO4'] = cost_MgSO4_chicago['total cost ($)']
cost_impacts_TES_chicago['cost saving - MgSO4'] = cost_impacts_TES_chicago['total cost - no TES'] - cost_impacts_TES_chicago['total cost - MgSO4']
cost_impacts_TES_chicago['cost saving % - MgSO4'] = cost_impacts_TES_chicago['cost saving - MgSO4']/cost_impacts_TES_chicago['total cost - no TES']
cost_impacts_TES_chicago['Salt Mass'] = load_chicago['MgSO4 Salt Mass']
cost_impacts_TES_chicago['cost saving kWh'] = cost_impacts_TES_chicago['cost saving - MgSO4']/cost_impacts_TES_chicago['Salt Mass']*20*0.75
cost_impacts_TES_chicago['City'] = 'Chicago'
cost_impacts_TES_chicago
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1          1988.733375         1908.164352
# 1              2           600.991030          574.077638
# 2              3           881.400116          846.361904
# 3              4          2919.712607         2807.579625
# 4              5          1383.027764         1324.478010
# ..           ...                  ...                 ...
# 395          396           928.541226          885.675787
# 396          397          1349.285509         1296.064398
# 397          398          1002.974575          956.149027
# 398          399          1156.008769         1112.380419
# 399          400          2015.559961         1936.461616
#
#      cost saving - MgSO4  cost saving % - MgSO4   Salt Mass  cost saving kWh  \
# 0              80.569023               0.040513   85.602490        14.117993
# 1              26.913392               0.044782   29.395790        13.733289
# ...

# %%
cost_impacts_TES_phoenix.min()
# Out:
# building id                     1
# total cost - no TES      0.456315
# total cost - MgSO4        0.37918
# cost saving - MgSO4      0.077135
# cost saving % - MgSO4    0.056166
# Salt Mass                2.107362
# cost saving kWh          0.549038
# City                      Phoenix
# dtype: object

# %%
cost_impacts_TES_dallas.max()
# Out:
# building id                     400
# total cost - no TES      581.597761
# total cost - MgSO4       545.820254
# cost saving - MgSO4       35.777507
# cost saving % - MgSO4      0.117558
# Salt Mass                 98.062927
# cost saving kWh            6.266217
# City                         Dallas
# dtype: object

# %%
# Find changes in total costs - Dallas:
cost_impacts_TES_dallas = pd.DataFrame()
cost_impacts_TES_dallas['building id'] = cost_noTES_dallas['building id']
cost_impacts_TES_dallas['total cost - no TES'] = cost_noTES_dallas['total cost ($)']
cost_impacts_TES_dallas['total cost - MgSO4'] = cost_MgSO4_dallas['total cost ($)']
cost_impacts_TES_dallas['cost saving - MgSO4'] = cost_impacts_TES_dallas['total cost - no TES'] - cost_impacts_TES_dallas['total cost - MgSO4']
cost_impacts_TES_dallas['cost saving % - MgSO4'] = cost_impacts_TES_dallas['cost saving - MgSO4']/cost_impacts_TES_dallas['total cost - no TES']
cost_impacts_TES_dallas['Salt Mass'] = load_dallas['MgSO4 Salt Mass']
cost_impacts_TES_dallas['cost saving kWh'] = cost_impacts_TES_dallas['cost saving - MgSO4']/cost_impacts_TES_dallas['Salt Mass']*20*0.75
cost_impacts_TES_dallas['City'] = 'Dallas'
cost_impacts_TES_dallas
# Out:
#      building id  total cost - no TES  total cost - MgSO4  \
# 0              1           141.306868          130.281894
# 1              2           269.676314          249.364618
# 2              3           125.066440          115.513270
# 3              4           129.434726          118.307288
# 4              5           240.749270          224.650982
# ..           ...                  ...                 ...
# 395          396            79.311925           72.739724
# 396          397           147.740908          136.792455
# 397          398           300.882286          282.147570
# 398          399            72.535163           66.745412
# 399          400           226.515551          209.763204
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0              11.024974               0.078022  34.461571         4.798812
# 1              20.311696               0.075319  63.757514         4.778659
# ...

# %%
# Create cost saving map:
# Map folder:
us_states = gpd.read_file('C:/Users/atpha/Documents/Research/PJM Maps/tl_2016_us_state/tl_2016_us_state.shp')
us_states_in_NA = us_states.drop(labels=[31, 34, 35, 36, 40, 41, 49], axis=0)

cost_saving_detroit = cost_impacts_TES_detroit['cost saving - MgSO4'].sum()
cost_saving_detroit_pct = cost_impacts_TES_detroit['cost saving - MgSO4'].sum()/cost_impacts_TES_detroit['total cost - no TES'].sum()
cost_saving_detroit_kg = cost_impacts_TES_detroit['cost saving - MgSO4'].sum()*20/cost_impacts_TES_detroit['Salt Mass'].sum()
cost_saving_detroit_kWh = cost_saving_detroit_kg*0.75

cost_saving_atlanta = cost_impacts_TES_atlanta['cost saving - MgSO4'].sum()
cost_saving_atlanta_pct = cost_impacts_TES_atlanta['cost saving - MgSO4'].sum()/cost_impacts_TES_atlanta['total cost - no TES'].sum()
cost_saving_atlanta_kg = cost_impacts_TES_atlanta['cost saving - MgSO4'].sum()*20/cost_impacts_TES_atlanta['Salt Mass'].sum()
cost_saving_atlanta_kWh = cost_saving_atlanta_kg*0.75

cost_saving_la = cost_impacts_TES_la['cost saving - MgSO4'].sum()
cost_saving_la_pct = cost_impacts_TES_la['cost saving - MgSO4'].sum()/cost_impacts_TES_la['total cost - no TES'].sum()
cost_saving_la_kg = cost_impacts_TES_la['cost saving - MgSO4'].sum()*20/cost_impacts_TES_la['Salt Mass'].sum()
cost_saving_la_kWh = cost_saving_la_kg*0.75

cost_saving_minneapolis = cost_impacts_TES_minneapolis['cost saving - MgSO4'].sum()
cost_saving_minneapolis_pct = cost_impacts_TES_minneapolis['cost saving - MgSO4'].sum()/cost_impacts_TES_minneapolis['total cost - no TES'].sum()
cost_saving_minneapolis_kg = cost_impacts_TES_minneapolis['cost saving - MgSO4'].sum()*20/cost_impacts_TES_minneapolis['Salt Mass'].sum()
cost_saving_minneapolis_kWh = cost_saving_minneapolis_kg*0.75

cost_saving_ny = cost_impacts_TES_ny['cost saving - MgSO4'].sum()
cost_saving_ny_pct = cost_impacts_TES_ny['cost saving - MgSO4'].sum()/cost_impacts_TES_ny['total cost - no TES'].sum()
cost_saving_ny_kg = cost_impacts_TES_ny['cost saving - MgSO4'].sum()*20/cost_impacts_TES_ny['Salt Mass'].sum()
cost_saving_ny_kWh = cost_saving_ny_kg*0.75

cost_saving_orlando = cost_impacts_TES_orlando['cost saving - MgSO4'].sum()
cost_saving_orlando_pct = cost_impacts_TES_orlando['cost saving - MgSO4'].sum()/cost_impacts_TES_orlando['total cost - no TES'].sum()
cost_saving_orlando_kg = cost_impacts_TES_orlando['cost saving - MgSO4'].sum()*20/cost_impacts_TES_orlando['Salt Mass'].sum()
cost_saving_orlando_kWh = cost_saving_orlando_kg*0.75

cost_saving_phoenix = cost_impacts_TES_phoenix['cost saving - MgSO4'].sum()
cost_saving_phoenix_pct = cost_impacts_TES_phoenix['cost saving - MgSO4'].sum()/cost_impacts_TES_phoenix['total cost - no TES'].sum()
cost_saving_phoenix_kg = cost_impacts_TES_phoenix['cost saving - MgSO4'].sum()*20/cost_impacts_TES_phoenix['Salt Mass'].sum()
cost_saving_phoenix_kWh = cost_saving_phoenix_kg*0.75

cost_saving_seattle = cost_impacts_TES_seattle['cost saving - MgSO4'].sum()
cost_saving_seattle_pct = cost_impacts_TES_seattle['cost saving - MgSO4'].sum()/cost_impacts_TES_seattle['total cost - no TES'].sum()
cost_saving_seattle_kg = cost_impacts_TES_seattle['cost saving - MgSO4'].sum()*20/cost_impacts_TES_seattle['Salt Mass'].sum()
cost_saving_seattle_kWh = cost_saving_seattle_kg*0.75

cost_saving_boston = cost_impacts_TES_boston['cost saving - MgSO4'].sum()
cost_saving_boston_pct = cost_impacts_TES_boston['cost saving - MgSO4'].sum()/cost_impacts_TES_boston['total cost - no TES'].sum()
cost_saving_boston_kg = cost_impacts_TES_boston['cost saving - MgSO4'].sum()*20/cost_impacts_TES_boston['Salt Mass'].sum()
cost_saving_boston_kWh = cost_saving_boston_kg*0.75

cost_saving_boulder = cost_impacts_TES_boulder['cost saving - MgSO4'].sum()
cost_saving_boulder_pct = cost_impacts_TES_boulder['cost saving - MgSO4'].sum()/cost_impacts_TES_boulder['total cost - no TES'].sum()
cost_saving_boulder_kg = cost_impacts_TES_boulder['cost saving - MgSO4'].sum()*20/cost_impacts_TES_boulder['Salt Mass'].sum()
cost_saving_boulder_kWh = cost_saving_boulder_kg*0.75

cost_saving_chicago = cost_impacts_TES_chicago['cost saving - MgSO4'].sum()
cost_saving_chicago_pct = cost_impacts_TES_chicago['cost saving - MgSO4'].sum()/cost_impacts_TES_chicago['total cost - no TES'].sum()
cost_saving_chicago_kg = cost_impacts_TES_chicago['cost saving - MgSO4'].sum()*20/cost_impacts_TES_chicago['Salt Mass'].sum()
cost_saving_chicago_kWh = cost_saving_chicago_kg*0.75

cost_saving_dallas = cost_impacts_TES_dallas['cost saving - MgSO4'].sum()
cost_saving_dallas_pct = cost_impacts_TES_dallas['cost saving - MgSO4'].sum()/cost_impacts_TES_dallas['total cost - no TES'].sum()
cost_saving_dallas_kg = cost_impacts_TES_dallas['cost saving - MgSO4'].sum()*20/cost_impacts_TES_dallas['Salt Mass'].sum()
cost_saving_dallas_kWh = cost_saving_dallas_kg*0.75

cost_saving_detroit_kWh
# Out:
# 17.28551270824886

# %%
# Location:
location_detroit = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\DTW.csv")
lon_detroit = location_detroit['lon'][0]
lat_detroit = location_detroit['lat'][0]

location_atlanta = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\ATL.csv")
lon_atlanta = location_atlanta['lon'][0]
lat_atlanta = location_atlanta['lat'][0]

location_la = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\LAX.csv")
lon_la = location_la['lon'][0]
lat_la = location_la['lat'][0]

location_minneapolis = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\MSP.csv")
lon_minneapolis = location_minneapolis['lon'][0]
lat_minneapolis = location_minneapolis['lat'][0]

location_ny = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\JFK.csv")
lon_ny = location_ny['lon'][0]
lat_ny = location_ny['lat'][0]

location_orlando = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\MCO.csv")
lon_orlando = location_orlando['lon'][0]
lat_orlando = location_orlando['lat'][0]

location_phoenix = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\PHX.csv")
lon_phoenix = location_phoenix['lon'][0]
lat_phoenix = location_phoenix['lat'][0]

location_seattle = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\SEA.csv")
lon_seattle = location_seattle['lon'][0]
lat_seattle = location_seattle['lat'][0]

location_boston = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\BOS.csv")
lon_boston = location_boston['lon'][0]
lat_boston = location_boston['lat'][0]

location_boulder = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\BDU.csv")
lon_boulder = location_boulder['lon'][0]
lat_boulder = location_boulder['lat'][0]

location_chicago = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\ORD.csv")
lon_chicago = location_chicago['lon'][0]
lat_chicago = location_chicago['lat'][0]

location_dallas = pd.read_csv(r"C:\Users\atpha\Documents\Postdocs\Projects\TES\Data\weather\DFW.csv")
lon_dallas = location_dallas['lon'][0]
lat_dallas = location_dallas['lat'][0]

# %%
city = ['Detroit', 'Atlanta', 'Los Angeles', 'New York City', 'Minneapolis', 'Orlando', 'Phoenix', 'Seattle', 'Boston', 'Boulder', 'Chicago', 'Dallas']

lon = [lon_detroit, lon_atlanta, lon_la, lon_ny, lon_minneapolis, lon_orlando, lon_phoenix, lon_seattle, lon_boston, lon_boulder, lon_chicago, lon_dallas]
lat = [lat_detroit, lat_atlanta, lat_la, lat_ny, lat_minneapolis, lat_orlando, lat_phoenix, lat_seattle, lat_boston, lat_boulder, lat_chicago, lat_dallas]
cost_saving = [cost_saving_detroit*664.3, cost_saving_atlanta*576.7, cost_saving_la*3610.0, cost_saving_ny*8509.9, cost_saving_minneapolis*448.9,
               cost_saving_orlando*311.0, cost_saving_phoenix*1507.7, cost_saving_seattle*803.4, cost_saving_boston*701.8, cost_saving_boulder*113.1,
               cost_saving_chicago*2964.5, cost_saving_dallas*1354.6]
cost_saving_kWh = [cost_saving_detroit_kWh, cost_saving_atlanta_kWh, cost_saving_la_kWh, cost_saving_ny_kWh, cost_saving_minneapolis_kWh,
                   cost_saving_orlando_kWh, cost_saving_phoenix_kWh, cost_saving_seattle_kWh, cost_saving_boston_kWh, cost_saving_boulder_kWh,
                   cost_saving_chicago_kWh, cost_saving_dallas_kWh]
cost_saving_pct = [cost_saving_detroit_pct*100, cost_saving_atlanta_pct*100, cost_saving_la_pct*100, cost_saving_ny_pct*100, cost_saving_minneapolis_pct*100,
                   cost_saving_orlando_pct*100, cost_saving_phoenix_pct*100, cost_saving_seattle_pct*100, cost_saving_boston_pct*100,
                   cost_saving_boulder_pct*100, cost_saving_chicago_pct*100, cost_saving_dallas_pct*100]

frame = np.vstack((city, lon, lat, cost_saving, cost_saving_pct, cost_saving_kWh))
frame = pd.DataFrame(frame)
frame = frame.transpose()
frame.rename({0: 'City', 1: 'lon', 2: 'lat', 3: 'Saving', 4: 'Saving %', 5: 'Saving kWh'},axis=1, inplace=True)
frame = frame.astype({'lon': float, 'lat': float, 'Saving': float, 'Saving %': float, 'Saving kWh': float})
frame
# Out:
#              City       lon      lat        Saving  Saving %  Saving kWh
# 0         Detroit  -83.3300  42.2300  1.365271e+07  3.475605   17.285513
# 1         Atlanta  -84.4418  33.6301  3.500617e+06  5.361498    6.604447
# 2     Los Angeles -118.3865  33.9382  7.598912e+06  5.539987    5.961140
# 3   New York City  -73.7622  40.6386  1.357365e+08  3.045245   12.519227
# 4     Minneapolis  -93.2313  44.8854  1.454180e+07  6.529862   25.537476
# 5         Orlando  -81.3090  28.4294  3.371238e+05  8.736634    2.356584
# 6         Phoenix -112.0116  33.4343  1.984928e+06  8.988615    3.596602
# 7         Seattle -122.3144  47.4447  2.516509e+06  2.864452    5.377904
# 8          Boston  -71.0097  42.3606  1.753120e+07  3.651143   18.873434
# 9         Boulder -105.2258  40.0394  2.499050e+06  9.207237   22.244770
# 10        Chicago  -87.9319  41.9875  4.863058e+07  4.308001   13.067542
# 11         Dallas  -97.0380  32.8968  6.095326e+06  7.095192    4.825030

# %%
frame.max()
# Out:
# City                   Seattle
# lon                   -71.0097
# lat                    47.4447
# Saving        135736478.595686
# Saving %              9.207237
# Saving kWh           25.537476
# dtype: object

# %%
frame.min()
# Out:
# City               Atlanta
# lon              -122.3144
# lat                28.4294
# Saving        337123.77338
# Saving %          2.864452
# Saving kWh        2.356584
# dtype: object

# %%
# Spatial join station data with states:
from shapely.geometry import Point
from geopandas import GeoDataFrame
geometry = [Point(xy) for xy in zip(frame['lon'], frame['lat'])]
gpdframe = GeoDataFrame(frame, crs='epsg:4269', geometry=geometry)
costsaving_map = gpd.sjoin(gpdframe, us_states_in_NA, how="inner", op='intersects')

# Cost saving map for all cities:
minx, miny, maxx, maxy = us_states_in_NA.total_bounds

fig, ax = plt.subplots()
ax.set_aspect('equal')
us_states_in_NA.plot(ax=ax, color='white', figsize=(10,4), edgecolors='black', linewidth=0.5)
costsaving_map.plot(ax=ax, kind="scatter", x="lon", y="lat", s=700, edgecolors='black', #label="Cost Saving due to TES (%)",
                    c="Saving %", cmap="Blues", colorbar=True, legend=False, alpha=1, figsize=(10,4))
plt.axis('off')
f = plt.gcf()
cax = f.get_axes()[1]
cax.tick_params(labelsize=14)
cax.set_ylabel("Cost Saving due to TES (%)", fontsize=14)
ax.set_xlim(minx, maxx)
ax.set_ylim(miny, maxy)
plt.tight_layout()
fig.savefig('C:/Users/atpha/Documents/Postdocs/Projects/TES/Draft/images/map_pct.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\atpha\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3309: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
costsaving_map.to_csv(r'C:\Users\atpha\Documents\Postdocs\Projects\TES\Results\cost_saving_sum.csv')

# %%
# Plot cost saving:
costsaving_map_noNY = costsaving_map[costsaving_map['City'] != 'New York City']
fig, ax = plt.subplots()
ax.set_aspect('equal')
us_states_in_NA.plot(ax=ax, color='white', edgecolors='black', linewidth=0.5)
costsaving_map.plot(ax=ax, kind="scatter", x="lon", y="lat", edgecolors='black', s=700, #label="Cost Saving due to TES (%)",
                    c=costsaving_map["Saving"]/1000000, cmap="Blues", colorbar=True, legend=True, alpha=1, figsize=(10,4))
plt.axis('off')
f = plt.gcf()
cax = f.get_axes()[1]
cax.tick_params(labelsize=14)
cax.set_ylabel("Annual Cost Saving due to TES (Million $)", fontsize=14)
ax.set_xlim(minx, maxx)
ax.set_ylim(miny, maxy)
plt.tight_layout()
fig.savefig('C:/Users/atpha/Documents/Postdocs/Projects/TES/Draft/images/map_mag.png', dpi=300, bbox_inches='tight')

# %%
# Cost saving her kWh
fig, ax = plt.subplots()
ax.set_aspect('equal')
us_states_in_NA.plot(ax=ax, color='white', edgecolors='black', linewidth=0.5)
costsaving_map.plot(ax=ax, kind="scatter", x="lon", y="lat", edgecolors='black', s=700, #label="Cost Saving due to TES (%)",
                    c=costsaving_map["Saving kWh"], cmap="Greens", colorbar=True, legend=True, alpha=1, figsize=(10,4))
plt.axis('off')
f = plt.gcf()
cax = f.get_axes()[1]
cax.tick_params(labelsize=14)
cax.set_ylabel("TES Break-even Cost ($/kWh thermal)", fontsize=14)
ax.set_xlim(minx, maxx)
ax.set_ylim(miny, maxy)
plt.tight_layout()
fig.savefig('C:/Users/atpha/Documents/Postdocs/Projects/TES/Draft/images/map_kwh.png', dpi=300, bbox_inches='tight')

# %%
cost_impacts_TES_atlanta_sort = cost_impacts_TES_atlanta.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_atlanta_sort = cost_impacts_TES_atlanta_sort.reset_index()
cost_impacts_TES_atlanta_sort['building order'] = cost_impacts_TES_atlanta_sort.index+1

cost_impacts_TES_detroit_sort = cost_impacts_TES_detroit.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_detroit_sort = cost_impacts_TES_detroit_sort.reset_index()
cost_impacts_TES_detroit_sort['building order'] = cost_impacts_TES_detroit_sort.index+1

cost_impacts_TES_la_sort = cost_impacts_TES_la.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_la_sort = cost_impacts_TES_la_sort.reset_index()
cost_impacts_TES_la_sort['building order'] = cost_impacts_TES_la_sort.index+1

cost_impacts_TES_minneapolis_sort = cost_impacts_TES_minneapolis.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_minneapolis_sort = cost_impacts_TES_minneapolis_sort.reset_index()
cost_impacts_TES_minneapolis_sort['building order'] = cost_impacts_TES_minneapolis_sort.index+1

cost_impacts_TES_ny_sort = cost_impacts_TES_ny.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_ny_sort = cost_impacts_TES_ny_sort.reset_index()
cost_impacts_TES_ny_sort['building order'] = cost_impacts_TES_ny_sort.index+1

cost_impacts_TES_orlando_sort = cost_impacts_TES_orlando.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_orlando_sort = cost_impacts_TES_orlando_sort.reset_index()
cost_impacts_TES_orlando_sort['building order'] = cost_impacts_TES_orlando_sort.index+1

cost_impacts_TES_phoenix_sort = cost_impacts_TES_phoenix.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_phoenix_sort = cost_impacts_TES_phoenix_sort.reset_index()
cost_impacts_TES_phoenix_sort['building order'] = cost_impacts_TES_phoenix_sort.index+1

cost_impacts_TES_seattle_sort = cost_impacts_TES_seattle.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_seattle_sort = cost_impacts_TES_seattle_sort.reset_index()
cost_impacts_TES_seattle_sort['building order'] = cost_impacts_TES_seattle_sort.index+1

cost_impacts_TES_boston_sort = cost_impacts_TES_boston.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_boston_sort = cost_impacts_TES_boston_sort.reset_index()
cost_impacts_TES_boston_sort['building order'] = cost_impacts_TES_boston_sort.index+1

cost_impacts_TES_boulder_sort = cost_impacts_TES_boulder.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_boulder_sort = cost_impacts_TES_boulder_sort.reset_index()
cost_impacts_TES_boulder_sort['building order'] = cost_impacts_TES_boulder_sort.index+1

cost_impacts_TES_chicago_sort = cost_impacts_TES_chicago.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_chicago_sort = cost_impacts_TES_chicago_sort.reset_index()
cost_impacts_TES_chicago_sort['building order'] = cost_impacts_TES_chicago_sort.index+1

cost_impacts_TES_dallas_sort = cost_impacts_TES_dallas.sort_values(by='cost saving % - MgSO4')
cost_impacts_TES_dallas_sort = cost_impacts_TES_dallas_sort.reset_index()
cost_impacts_TES_dallas_sort['building order'] = cost_impacts_TES_dallas_sort.index+1

cost_impacts_TES_dallas_sort
# Out:
#      index  building id  total cost - no TES  total cost - MgSO4  \
# 0       21           22           300.620659          283.763403
# 1      249          250           282.590281          266.721872
# 2       39           40           261.884344          247.055570
# 3      356          357           217.255067          204.924205
# 4      176          177           397.584798          374.594650
# ..     ...          ...                  ...                 ...
# 395    337          338            64.165638           57.782931
# 396    228          229            34.873144           31.387900
# 397    233          234            41.584985           37.386619
# 398    182          183            44.439766           39.716158
# 399    100          101            20.121292           17.755882
#
#      cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0              16.857256               0.056075  45.198943         5.594353
# ...

# %%
all_cities = pd.concat([cost_impacts_TES_atlanta_sort, cost_impacts_TES_detroit_sort, cost_impacts_TES_la_sort, cost_impacts_TES_ny_sort,
                        cost_impacts_TES_minneapolis_sort, cost_impacts_TES_orlando_sort, cost_impacts_TES_phoenix_sort,
                        cost_impacts_TES_seattle_sort, cost_impacts_TES_boston_sort, cost_impacts_TES_boulder_sort,
                        cost_impacts_TES_chicago_sort, cost_impacts_TES_dallas_sort], ignore_index=True)
all_cities['cost saving %'] = all_cities['cost saving % - MgSO4']*100

# %%
import altair as alt
from textwrap import wrap
alt.Chart(all_cities).mark_bar(size=1,color="skyblue").encode(
    y=alt.Y('cost saving %', axis=alt.Axis(grid=False, title='Cost Saving Due to TES (%)')),
    x=alt.X('building order', title=None, sort=alt.EncodingSortField(field="building order", op="count", order='ascending')),
    #order=alt.Order('Technology', sort='ascending'),
    #color=alt.Color('cost saving % - MgSO4', scale=alt.Scale(range=['skyblue'])),
    facet=alt.Facet('City', columns=6, title=None, header=alt.Header(labelFontSize=18), sort=None)
).configure_axis(titleFontSize=17, labelFontSize=16, grid=False).configure_legend(labelFontSize=18, titleFontSize=18
                                                                      ).properties(width=125, height=200).show()
# Out:
# Displaying chart at http://localhost:50849/

# %%
cost_impacts_TES_atlanta_sort2 = cost_impacts_TES_atlanta.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_atlanta_sort2 = cost_impacts_TES_atlanta_sort2.reset_index()
cost_impacts_TES_atlanta_sort2['building order'] = cost_impacts_TES_atlanta_sort2.index+1

cost_impacts_TES_detroit_sort2 = cost_impacts_TES_detroit.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_detroit_sort2 = cost_impacts_TES_detroit_sort2.reset_index()
cost_impacts_TES_detroit_sort2['building order'] = cost_impacts_TES_detroit_sort2.index+1

cost_impacts_TES_la_sort2 = cost_impacts_TES_la.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_la_sort2 = cost_impacts_TES_la_sort2.reset_index()
cost_impacts_TES_la_sort2['building order'] = cost_impacts_TES_la_sort2.index+1

cost_impacts_TES_minneapolis_sort2 = cost_impacts_TES_minneapolis.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_minneapolis_sort2 = cost_impacts_TES_minneapolis_sort2.reset_index()
cost_impacts_TES_minneapolis_sort2['building order'] = cost_impacts_TES_minneapolis_sort2.index+1

cost_impacts_TES_ny_sort2 = cost_impacts_TES_ny.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_ny_sort2 = cost_impacts_TES_ny_sort2.reset_index()
cost_impacts_TES_ny_sort2['building order'] = cost_impacts_TES_ny_sort2.index+1

cost_impacts_TES_orlando_sort2 = cost_impacts_TES_orlando.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_orlando_sort2 = cost_impacts_TES_orlando_sort2.reset_index()
cost_impacts_TES_orlando_sort2['building order'] = cost_impacts_TES_orlando_sort2.index+1

cost_impacts_TES_phoenix_sort2 = cost_impacts_TES_phoenix.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_phoenix_sort2 = cost_impacts_TES_phoenix_sort2.reset_index()
cost_impacts_TES_phoenix_sort2['building order'] = cost_impacts_TES_phoenix_sort2.index+1

cost_impacts_TES_seattle_sort2 = cost_impacts_TES_seattle.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_seattle_sort2 = cost_impacts_TES_seattle_sort2.reset_index()
cost_impacts_TES_seattle_sort2['building order'] = cost_impacts_TES_seattle_sort2.index+1

cost_impacts_TES_boston_sort2 = cost_impacts_TES_boston.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_boston_sort2 = cost_impacts_TES_boston_sort2.reset_index()
cost_impacts_TES_boston_sort2['building order'] = cost_impacts_TES_boston_sort2.index+1

cost_impacts_TES_boulder_sort2 = cost_impacts_TES_boulder.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_boulder_sort2 = cost_impacts_TES_boulder_sort2.reset_index()
cost_impacts_TES_boulder_sort2['building order'] = cost_impacts_TES_boulder_sort2.index+1

cost_impacts_TES_chicago_sort2 = cost_impacts_TES_chicago.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_chicago_sort2 = cost_impacts_TES_chicago_sort2.reset_index()
cost_impacts_TES_chicago_sort2['building order'] = cost_impacts_TES_chicago_sort2.index+1

cost_impacts_TES_dallas_sort2 = cost_impacts_TES_dallas.sort_values(by='cost saving - MgSO4')
cost_impacts_TES_dallas_sort2 = cost_impacts_TES_dallas_sort2.reset_index()
cost_impacts_TES_dallas_sort2['building order'] = cost_impacts_TES_dallas_sort2.index+1

all_cities2 = pd.concat([cost_impacts_TES_atlanta_sort2, cost_impacts_TES_detroit_sort2, cost_impacts_TES_la_sort2, cost_impacts_TES_ny_sort2,
                         cost_impacts_TES_minneapolis_sort2, cost_impacts_TES_orlando_sort2, cost_impacts_TES_phoenix_sort2,
                         cost_impacts_TES_seattle_sort2, cost_impacts_TES_boston_sort2, cost_impacts_TES_boulder_sort2,
                         cost_impacts_TES_chicago_sort2, cost_impacts_TES_dallas_sort2], ignore_index=True)
all_cities2['cost saving'] = all_cities2['cost saving - MgSO4']
all_cities2
# Out:
#       index  building id  total cost - no TES  total cost - MgSO4  \
# 0       237          238            26.693631           24.308556
# 1         0            1            29.859611           27.267587
# 2       107          108            43.866673           40.989114
# 3       252          253            45.463017           42.343482
# 4       228          229            42.191513           39.047120
# ...     ...          ...                  ...                 ...
# 4795     33           34           437.108668          407.090896
# 4796    183          184           465.922038          435.297699
# 4797    310          311           498.293044          466.856212
# 4798    382          383           548.640282          513.743234
# 4799    167          168           581.597761          545.820254
#
#       cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0                2.385075               0.089350   7.688556         4.653166
# ...

# %%
all_cities2.to_csv(r'C:\Users\atpha\Documents\Postdocs\Projects\TES\Results\cost_saving_all.csv')

# %%
alt.Chart(all_cities2).mark_bar(size=1,color="skyblue").encode(
    y=alt.Y('cost saving', axis=alt.Axis(grid=False, title='Cost Saving Due to TES ($)')),
    x=alt.X('building order', title=None, sort=alt.EncodingSortField(field="building order", op="count", order='ascending')),
    #order=alt.Order('Technology', sort='ascending'),
    #color=alt.Color('cost saving % - MgSO4', scale=alt.Scale(range=['skyblue'])),
    facet=alt.Facet('City', columns=6, title=None, header=alt.Header(labelFontSize=18), sort=None)
).configure_axis(titleFontSize=17, labelFontSize=16, grid=False).configure_legend(labelFontSize=18, titleFontSize=18
                                                                                  ).properties(width=125, height=200).show()
# Out:
# Displaying chart at http://localhost:50849/

# %%
# Cost per kWh thermal:
cost_impacts_TES_atlanta_sort3 = cost_impacts_TES_atlanta.sort_values(by='cost saving kWh')
cost_impacts_TES_atlanta_sort3 = cost_impacts_TES_atlanta_sort3.reset_index()
cost_impacts_TES_atlanta_sort3['building order'] = cost_impacts_TES_atlanta_sort3.index+1

cost_impacts_TES_detroit_sort3 = cost_impacts_TES_detroit.sort_values(by='cost saving kWh')
cost_impacts_TES_detroit_sort3 = cost_impacts_TES_detroit_sort3.reset_index()
cost_impacts_TES_detroit_sort3['building order'] = cost_impacts_TES_detroit_sort3.index+1

cost_impacts_TES_la_sort3 = cost_impacts_TES_la.sort_values(by='cost saving kWh')
cost_impacts_TES_la_sort3 = cost_impacts_TES_la_sort3.reset_index()
cost_impacts_TES_la_sort3['building order'] = cost_impacts_TES_la_sort3.index+1

cost_impacts_TES_minneapolis_sort3 = cost_impacts_TES_minneapolis.sort_values(by='cost saving kWh')
cost_impacts_TES_minneapolis_sort3 = cost_impacts_TES_minneapolis_sort3.reset_index()
cost_impacts_TES_minneapolis_sort3['building order'] = cost_impacts_TES_minneapolis_sort3.index+1

cost_impacts_TES_ny_sort3 = cost_impacts_TES_ny.sort_values(by='cost saving kWh')
cost_impacts_TES_ny_sort3 = cost_impacts_TES_ny_sort3.reset_index()
cost_impacts_TES_ny_sort3['building order'] = cost_impacts_TES_ny_sort3.index+1

cost_impacts_TES_orlando_sort3 = cost_impacts_TES_orlando.sort_values(by='cost saving kWh')
cost_impacts_TES_orlando_sort3 = cost_impacts_TES_orlando_sort3.reset_index()
cost_impacts_TES_orlando_sort3['building order'] = cost_impacts_TES_orlando_sort3.index+1

cost_impacts_TES_phoenix_sort3 = cost_impacts_TES_phoenix.sort_values(by='cost saving kWh')
cost_impacts_TES_phoenix_sort3 = cost_impacts_TES_phoenix_sort3.reset_index()
cost_impacts_TES_phoenix_sort3['building order'] = cost_impacts_TES_phoenix_sort3.index+1

cost_impacts_TES_seattle_sort3 = cost_impacts_TES_seattle.sort_values(by='cost saving kWh')
cost_impacts_TES_seattle_sort3 = cost_impacts_TES_seattle_sort3.reset_index()
cost_impacts_TES_seattle_sort3['building order'] = cost_impacts_TES_seattle_sort3.index+1

cost_impacts_TES_boston_sort3 = cost_impacts_TES_boston.sort_values(by='cost saving kWh')
cost_impacts_TES_boston_sort3 = cost_impacts_TES_boston_sort3.reset_index()
cost_impacts_TES_boston_sort3['building order'] = cost_impacts_TES_boston_sort3.index+1

cost_impacts_TES_boulder_sort3 = cost_impacts_TES_boulder.sort_values(by='cost saving kWh')
cost_impacts_TES_boulder_sort3 = cost_impacts_TES_boulder_sort3.reset_index()
cost_impacts_TES_boulder_sort3['building order'] = cost_impacts_TES_boulder_sort3.index+1

cost_impacts_TES_chicago_sort3 = cost_impacts_TES_chicago.sort_values(by='cost saving kWh')
cost_impacts_TES_chicago_sort3 = cost_impacts_TES_chicago_sort3.reset_index()
cost_impacts_TES_chicago_sort3['building order'] = cost_impacts_TES_chicago_sort3.index+1

cost_impacts_TES_dallas_sort3 = cost_impacts_TES_dallas.sort_values(by='cost saving kWh')
cost_impacts_TES_dallas_sort3 = cost_impacts_TES_dallas_sort3.reset_index()
cost_impacts_TES_dallas_sort3['building order'] = cost_impacts_TES_dallas_sort3.index+1

all_cities3 = pd.concat([cost_impacts_TES_atlanta_sort3, cost_impacts_TES_detroit_sort3, cost_impacts_TES_la_sort3, cost_impacts_TES_ny_sort3,
                         cost_impacts_TES_minneapolis_sort3, cost_impacts_TES_orlando_sort3, cost_impacts_TES_phoenix_sort3,
                         cost_impacts_TES_seattle_sort3, cost_impacts_TES_boston_sort3, cost_impacts_TES_boulder_sort3,
                         cost_impacts_TES_chicago_sort3, cost_impacts_TES_dallas_sort3], ignore_index=True)
all_cities3['cost saving'] = all_cities3['cost saving kWh']
all_cities3
# Out:
#       index  building id  total cost - no TES  total cost - MgSO4  \
# 0       307          308            59.152387           54.428834
# 1       232          233           141.850446          132.016288
# 2        94           95           127.132333          119.195694
# 3       252          253            45.463017           42.343482
# 4       107          108            43.866673           40.989114
# ...     ...          ...                  ...                 ...
# 4795    319          320           351.370625          328.438278
# 4796      4            5           240.749270          224.650982
# 4797     71           72           296.966564          276.924630
# 4798    258          259           259.378627          243.212634
# 4799    382          383           548.640282          513.743234
#
#       cost saving - MgSO4  cost saving % - MgSO4  Salt Mass  cost saving kWh  \
# 0                4.723553               0.079854  19.246122         3.681432
# ...

# %%
chart = alt.Chart(all_cities3).mark_bar(size=1,color="darkseagreen").encode(
    y=alt.Y('cost saving kWh', axis=alt.Axis(grid=False, title='Break-even Cost ($/kWh)')),
    x=alt.X('building order', title=None, sort=alt.EncodingSortField(field="building order", op="count", order='ascending')),
    #order=alt.Order('Technology', sort='ascending'),
    #color=alt.Color('cost saving % - MgSO4', scale=alt.Scale(range=['skyblue'])),
    facet=alt.Facet('City', columns=6, title=None, header=alt.Header(labelFontSize=18), sort=None)
).configure_axis(titleFontSize=17, labelFontSize=16, grid=False).configure_legend(labelFontSize=18, titleFontSize=18
                                                                                  ).properties(width=125, height=200).show()
# Out:
# Displaying chart at http://localhost:50849/
